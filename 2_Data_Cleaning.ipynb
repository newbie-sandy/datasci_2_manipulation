# %% [markdown]
# <a href="https://colab.research.google.com/github/newbie-sandy/datasci_2_manipulation/blob/main/2_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %% [markdown]
# ## Load Dataset

# %%
data = pd.read_csv('/content/healthcare_data_cleaning (1).csv')

# %%
missing_data = data == 'missing','None'

# %%
missing_data
# Out:
# (        Patient Age  Gender  City of Residence  State of Residence  \
#  0             False   False              False               False
#  1             False   False              False               False
#  2             False   False              False               False
#  3             False   False              False               False
#  4             False   False              False               False
#  ...             ...     ...                ...                 ...
#  104995        False   False              False               False
#  104996        False   False              False               False
#  104997        False   False              False               False
#  104998         True   False              False                True
#  104999        False   False              False               False
#
#          Has Insurance  Visited Last Month  Payment Method  Preferred Doctor  \
#  0               False               False           False             False
#  1               False               False           False             False
#  2               False               False           False             False
#  3               False                True           False             False
#  4               False               False           False             False
#  ...               ...                 ...             ...               ...
#  104995          False               False           False             False
#  104996          False               False           False             False
#  104997          False               False           False             False
#  104998          False               False           False             False
#  104999          False               False           False             False
#
#          Disease Diagnosed  Medication Prescribed  Type of Appointment  \
#  0                   False                  False                False
#  1                   False                  False                False
#  2                   False                  False                False
#  3                   False                  False                False
#  4                   False                  False                False
#  ...                   ...                    ...                  ...
#  104995              False                  False                False
#  104996              False                  False                False
#  104997              False                  False                False
#  104998              False                  False                False
#  104999              False                  False                False
#
#          Average Heart Rate  Average BP  Height (in cm)  Weight (in kg)  \
#  0                    False       False           False           False
#  1                    False        True           False           False
#  2                    False       False           False           False
#  3                    False       False           False           False
#  4                    False       False           False           False
#  ...                    ...         ...             ...             ...
#  104995               False       False           False           False
#  104996                True       False           False           False
#  104997               False       False           False           False
#  104998               False       False           False           False
#  104999               False       False           False           False
#
#          Payment Due ($)  Last Visit (days ago)  Visit Duration (mins)  \
#  0                 False                  False                  False
#  1                 False                  False                   True
#  2                 False                   True                  False
#  3                 False                  False                  False
#  4                 False                  False                  False
#  ...                 ...                    ...                    ...
#  104995            False                  False                  False
#  104996             True                  False                  False
#  104997            False                  False                  False
#  104998            False                  False                  False
#  104999            False                  False                  False
#
#          Number of Tests  Prescription Cost ($)
#  0                 False                  False
#  1                 False                  False
#  2                 False                  False
#  3                 False                  False
#  4                 False                  False
#  ...                 ...                    ...
#  104995            False                  False
#  104996            False                  False
#  104997            False                  False
#  104998             True                  False
#  104999             True                  False
#
#  [105000 rows x 20 columns],
#  'None')

# %% [markdown]
# # Data Cleaning with Pandas:

# %% [markdown]
# ## Identify and handle missing values in the dataset.

# %%
# filling missing data represented using str"missing" with pd.NA
missing_data = data == 'missing'
df = data.copy()
df[missing_data] = pd.NA

# %%
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998        <NA>  Female       Heidiborough               <NA>
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes               <NA>           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
# 104999            No                Yes           Cash        Dr. Brown
#
#        Disease Diagnosed Medication Prescribed Type of Appointment  \
# 0                    Flu                 Med_E             General
# 1                    Flu                 Med_B          Specialist
# 2               Covid-19                 Med_D             General
# 3                    Flu                 Med_A             General
# 4                   None                 Med_C          Specialist
# ...                  ...                   ...                 ...
# 104995          Covid-19                 Med_E          Specialist
# 104996          Covid-19                 Med_C             General
# 104997           Allergy                 Med_D           Follow-Up
# 104998          Covid-19                 Med_A           Follow-Up
# 104999           Allergy                 Med_D             General
#
#        Average Heart Rate Average BP Height (in cm) Weight (in kg)  \
# 0                      66        111            183             70
# 1                      59       <NA>            174             58
# 2                      79        119            161             56
# 3                      99        115            171             52
# 4                      93         89            186             87
# ...                   ...        ...            ...            ...
# 104995                 65        112            169             61
# 104996               <NA>        111            165             67
# 104997                 89        118            179             71
# 104998                 74        123            167             75
# 104999                 77        140            167             62
#
#            Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195                  <NA>
# 2        315.0709305262176                  <NA>                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104995  309.16444606680665                   183                    10
# 104996                <NA>                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
# 104999  454.94983945860804                   167                    81
#
#        Number of Tests Prescription Cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998            <NA>     124.4083409893742
# 104999            <NA>     87.91060149353706
#
# [105000 rows x 20 columns]

# %% [markdown]
# ## Remove any duplicate rows and columns, if they exist.
#
# Result: duplicate rows and column don't exist.

# %%
# Identify duplicate columns
duplicate_columns = data.columns[data.columns.duplicated(keep='first')]

# %%
# Print the duplicate columns
print(duplicate_columns)
# Out:
# Index([], dtype='object')

# %%
# Remove duplicate columns
data = data.loc[:, ~data.columns.duplicated(keep='first')]

# %%
# Identify duplicate rows
duplicate_rows = data[data.duplicated(keep='first')]

# %%
# Print or inspect the duplicate rows
print(duplicate_rows)
# Out:
#        Patient Age  Gender    City of Residence State of Residence  \
# 1352            55   Other      South Debraview           Oklahoma
# 2124            35  Female           Sandraview            Alabama
# 2131            27    Male             Youngton           Illinois
# 2610            46   Other           Port Tammy           Oklahoma
# 3733            18    Male  South Benjaminmouth            Indiana
# ...            ...     ...                  ...                ...
# 104951          23   Other  North Catherineside              Idaho
# 104955          48  Female           Teresafort          Louisiana
# 104959          35  Female        Chandlerburgh           Kentucky
# 104984          42   Other          New Beverly        Mississippi
# 104999          45  Female        South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 1352         missing                Yes      Insurance        Dr. Smith
# 2124              No                Yes           Cash        Dr. Smith
# 2131             Yes                 No      Insurance        Dr. Jones
# 2610             Yes                 No           Cash      Dr. Johnson
# 3733              No                 No           Cash     Dr. Williams
# ...              ...                ...            ...              ...
# 104951            No                Yes           Card          missing
# 104955            No                Yes           Card          missing
# 104959            No                Yes      Insurance     Dr. Williams
# 104984            No                Yes           Card        Dr. Smith
# 104999            No                Yes           Cash        Dr. Brown
#
#        Disease Diagnosed Medication Prescribed Type of Appointment  \
# 1352                Cold                 Med_D           Emergency
# 2124                None                 Med_E             missing
# 2131             Allergy                 Med_A           Follow-Up
# 2610                 Flu                 Med_B             missing
# 3733                None                 Med_E           Emergency
# ...                  ...                   ...                 ...
# 104951              None                 Med_C           Follow-Up
# 104955           Allergy                 Med_E           Emergency
# 104959          Covid-19                 Med_C           Follow-Up
# 104984              None                 Med_E          Specialist
# 104999           Allergy                 Med_D             General
#
#        Average Heart Rate Average BP Height (in cm) Weight (in kg)  \
# 1352                   62        110            174             50
# 2124                   74        128            163             75
# 2131                   73        107            160        missing
# 2610                   77         98            172             46
# 3733                   80        121            190             79
# ...                   ...        ...            ...            ...
# 104951                 70        115            187             81
# 104955                 61        130            165            106
# 104959                 69        113            203             72
# 104984                 76        109            154             96
# 104999                 77        140            167             62
#
#            Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 1352    191.90038218861167                   186                    46
# 2124     320.6150148273086                   183                    70
# 2131     220.7284958518252                   171                    25
# 2610     39.70625027629493                   192                   109
# 3733    310.24835864601096                   198                    98
# ...                    ...                   ...                   ...
# 104951   217.2520829184622                   206                    86
# 104955  486.46058526704815                   165                    21
# 104959   193.9677987050666                   167                    43
# 104984  466.89144565098144                   198                    33
# 104999  454.94983945860804                   167                    81
#
#        Number of Tests Prescription Cost ($)
# 1352                 4     8.936784986821367
# 2124                 5    57.776335029625415
# 2131                 6     125.1623364903624
# 2610                 3     8.006275311330956
# 3733           missing     63.75471710909792
# ...                ...                   ...
# 104951               7    11.711305509556485
# 104955               3    112.29103168658735
# 104959               3    31.428202417550345
# 104984               4     47.09312026855614
# 104999         missing     87.91060149353706
#
# [5000 rows x 20 columns]

# %%
# Remove duplicate rows
data = data.drop_duplicates(keep='first')

# %% [markdown]
# ## Clean column names

# %% [markdown]
# # Data Transformation:

# %% [markdown]
# ## Create new columns based on existing ones (e.g., if you have a 'birth_date' column, create an 'age' column).
#
# Created a new "Weight (in lb)" column based on "Weight (in kg)"

# %%
df.dtypes
# Out:
# Patient Age              object
# Gender                   object
# City of Residence        object
# State of Residence       object
# Has Insurance            object
# Visited Last Month       object
# Payment Method           object
# Preferred Doctor         object
# Disease Diagnosed        object
# Medication Prescribed    object
# Type of Appointment      object
# Average Heart Rate       object
# Average BP               object
# Height (in cm)           object
# Weight (in kg)           object
# Payment Due ($)          object
# Last Visit (days ago)    object
# Visit Duration (mins)    object
# Number of Tests          object
# Prescription Cost ($)    object
# dtype: object

# %%
# Convert the column to numeric, coercing invalid values to NaN
df['Weight (in kg)'] = pd.to_numeric(df['Weight (in kg)'],errors= 'coerce',downcast='integer')

# %%
# Create column Weight (in lb)
df['Weight (in lb)'] = df['Weight (in kg)'] * 2.20462

# %%
# Insert the new column after the exisiting one
column_position = df.columns.get_loc('Weight (in kg)') + 1  # Get the index of 'W in kg' and add 1 to place it after
df.insert(column_position, 'Weight (in lb)', df.pop('Weight (in lb)'))  # Pop the column and insert it in the desired position

# %%
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998        <NA>  Female       Heidiborough               <NA>
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# 1                 No                Yes           Card      Dr. Johnson
# 2                Yes                 No           Cash     Dr. Williams
# 3                Yes               <NA>           Cash     Dr. Williams
# 4                 No                 No      Insurance        Dr. Brown
# ...              ...                ...            ...              ...
# 104995           Yes                 No           Card     Dr. Williams
# 104996           Yes                 No           Cash        Dr. Jones
# 104997           Yes                Yes      Insurance     Dr. Williams
# 104998           Yes                 No           Cash        Dr. Smith
# 104999            No                Yes           Cash        Dr. Brown
#
#        Disease Diagnosed Medication Prescribed  ... Average Heart Rate  \
# 0                    Flu                 Med_E  ...                 66
# 1                    Flu                 Med_B  ...                 59
# 2               Covid-19                 Med_D  ...                 79
# 3                    Flu                 Med_A  ...                 99
# 4                   None                 Med_C  ...                 93
# ...                  ...                   ...  ...                ...
# 104995          Covid-19                 Med_E  ...                 65
# 104996          Covid-19                 Med_C  ...               <NA>
# 104997           Allergy                 Med_D  ...                 89
# 104998          Covid-19                 Med_A  ...                 74
# 104999           Allergy                 Med_D  ...                 77
#
#        Average BP Height (in cm) Weight (in kg)  Weight (in lb)  \
# 0             111            183           70.0       154.32340
# 1            <NA>            174           58.0       127.86796
# 2             119            161           56.0       123.45872
# 3             115            171           52.0       114.64024
# 4              89            186           87.0       191.80194
# ...           ...            ...            ...             ...
# 104995        112            169           61.0       134.48182
# 104996        111            165           67.0       147.70954
# 104997        118            179           71.0       156.52802
# 104998        123            167           75.0       165.34650
# 104999        140            167           62.0       136.68644
#
#            Payment Due ($) Last Visit (days ago) Visit Duration (mins)  \
# 0        65.45721578126224                   193                    92
# 1       430.68365678679174                   195                  <NA>
# 2        315.0709305262176                  <NA>                    37
# 3        320.2998987723972                   175                   108
# 4        264.2147372473319                   188                   113
# ...                    ...                   ...                   ...
# 104995  309.16444606680665                   183                    10
# 104996                <NA>                   191                    47
# 104997   320.8304180033907                   172                    39
# 104998   5.341231420036174                   180                    79
# 104999  454.94983945860804                   167                    81
#
#        Number of Tests Prescription Cost ($)
# 0                    5     15.71751735532889
# 1                    4     80.78647284463952
# 2                    2      64.3921393009105
# 3                    2     8.872859215315316
# 4                    3     77.48311304645532
# ...                ...                   ...
# 104995               3     63.20478776719894
# 104996               2    113.86764025370326
# 104997               3    35.622420232475356
# 104998            <NA>     124.4083409893742
# 104999            <NA>     87.91060149353706
#
# [105000 rows x 21 columns]

# %% [markdown]
# ## Aggregate data using groupby and compute summary statistics.
#
# The pivot shows only numeric dtype columns

# %%
df.groupby('Disease Diagnosed').sum()
# Out:
# <ipython-input-192-25e6356bb4dc>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Disease Diagnosed').sum()
#                    Weight (in kg)  Weight (in lb)
# Disease Diagnosed
# Allergy                 1327332.0    2.926263e+06
# Cold                    1318762.0    2.907369e+06
# Covid-19                1305749.0    2.878680e+06
# Flu                     1322500.0    2.915610e+06
# None                    1325458.0    2.922131e+06

# %% [markdown]
# ## Use pivot tables or cross-tabulations for multi-dimensional analysis.
#
# What is the unique 5 about?

# %%
disease_and_medication = df[['Disease Diagnosed','Preferred Doctor','Visit Duration (mins)',"Medication Prescribed"]]
disease_and_medication.describe()
# Out:
#        Disease Diagnosed Preferred Doctor Visit Duration (mins)  \
# count              99729            99753                 99724
# unique                 5                5                   111
# top                  Flu        Dr. Jones                    49
# freq               20040            20086                   980
#
#        Medication Prescribed
# count                  99738
# unique                     5
# top                    Med_C
# freq                   20112
